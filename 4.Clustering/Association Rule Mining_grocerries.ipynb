# %%
import numpy as np  
import matplotlib.pyplot as plt
import pandas as pd  
from apyori import apriori

# %%
store_data = pd.read_csv("data/groceries - groceries.csv")
store_data.head()
# Out:
#    Item(s)            Item 1               Item 2          Item 3  \
# 0        4      citrus fruit  semi-finished bread       margarine
# 1        3    tropical fruit               yogurt          coffee
# 2        1        whole milk                  NaN             NaN
# 3        4         pip fruit               yogurt    cream cheese
# 4        4  other vegetables           whole milk  condensed milk
#
#                      Item 4 Item 5 Item 6 Item 7 Item 8 Item 9  ... Item 23  \
# 0               ready soups    NaN    NaN    NaN    NaN    NaN  ...     NaN
# 1                       NaN    NaN    NaN    NaN    NaN    NaN  ...     NaN
# 2                       NaN    NaN    NaN    NaN    NaN    NaN  ...     NaN
# 3              meat spreads    NaN    NaN    NaN    NaN    NaN  ...     NaN
# 4  long life bakery product    NaN    NaN    NaN    NaN    NaN  ...     NaN
#
#   Item 24 Item 25 Item 26 Item 27 Item 28 Item 29 Item 30 Item 31 Item 32
# 0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
# [5 rows x 33 columns]

# %%
store_data.shape
# Out:
# (9835, 33)

# %%
store_data = store_data.iloc[:,1:]
store_data.shape
# Out:
# (9835, 32)

# %%
# Convert pandas data frame into list such that each row of store_data becomes an item in the new list
records = []
for i in range(0, 1000):
    records.append([str(store_data.values[i,j]) for j in range(0, store_data.shape[1])])

# Each item in the record list will include items bought by a customer
records[0]

# %%
unique_items = [x for y in records for x in y]
print("Total Unique Items are %s"%(len(set(unique_items))))
# Out:
# Total Unique Items are 157

# %%
association_rules = apriori(records, min_support=0.008, min_confidence=0.3, min_lift=3, min_length=2)  
association_results = list(association_rules)

# %%
# Lets review rules being generated by Apriori algorithm
print("Total Rules or commonly observed itemset in store_data basis the support & confidence threshold is %s"
     # %len(association_results))
# Out:
# Total Rules or commonly observed itemset in store_data basis the support & confidence threshold is 78

# %%
for item in association_results:

    # first index of the inner list
    # Contains base item and add item
    pair = item[0] 
    items = [x for x in pair]
    print("Rule: " + items[0] + " -> " + items[1])

    #second index of the inner list
    print("Support: " + str(item[1]))

    #third index of the list located at 0th
    #of the third index of the inner list

    print("Confidence: " + str(item[2][0][2]))
    print("Lift: " + str(item[2][0][3]))
    print("=====================================")
# Out:
# Rule: whipped/sour cream -> berries
# Support: 0.017
# Confidence: 0.3617021276595745
# Lift: 4.88786658999425
# =====================================
# Rule: root vegetables -> butter
# Support: 0.017
# Confidence: 0.3695652173913044
# Lift: 3.3596837944664033
# =====================================
# Rule: candy -> tropical fruit
# Support: 0.009
# Confidence: 0.35999999999999993
# Lift: 3.7113402061855663
# =====================================
# Rule: long life bakery product -> coffee
# Support: 0.008
# Confidence: 0.3076923076923077
# Lift: 4.048582995951417
# =====================================
# Rule: curd -> sliced cheese
# Support: 0.009
# Confidence: 0.3214285714285714
# Lift: 4.285714285714286
# =====================================
# Rule: whipped/sour cream -> ham
# Support: 0.008
# Confidence: 0.38095238095238093
# Lift: 5.148005148005148
# =====================================
# Rule: hard cheese -> tropical fruit
# Support: 0.009
# Confidence: 0.37499999999999994
# Lift: 3.865979381443298
# =====================================
# Rule: oil -> newspapers
# Support: 0.01
# Confidence: 0.33333333333333337
# Lift: 3.745318352059926
# =====================================
# Rule: root vegetables -> packaged fruit/vegetables
# Support: 0.011
# Confidence: 0.3333333333333333
# Lift: 3.0303030303030303
# =====================================
# Rule: pip fruit -> tropical fruit
# Support: 0.013
# Confidence: 0.31707317073170727
# Lift: 3.268795574553683
# =====================================
# Rule: yogurt -> sliced cheese
# Support: 0.011
# Confidence: 0.39285714285714285
# Lift: 3.093363329583802
# =====================================
# Rule: beef -> whole milk
# Support: 0.01
# Confidence: 0.3703703703703704
# Lift: 3.367003367003367
# =====================================
# Rule: whipped/sour cream -> nan
# Support: 0.017
# Confidence: 0.3617021276595745
# Lift: 4.88786658999425
# =====================================
# Rule: root vegetables -> whole milk
# Support: 0.008
# Confidence: 0.36363636363636365
# Lift: 3.3057851239669422
# =====================================
# Rule: whipped/sour cream -> whole milk
# Support: 0.01
# Confidence: 0.4545454545454546
# Lift: 6.142506142506144
# =====================================
# Rule: yogurt -> citrus fruit
# Support: 0.008
# Confidence: 0.47058823529411764
# Lift: 3.7054191755442334
# =====================================
# Rule: domestic eggs -> bottled water
# Support: 0.008
# Confidence: 0.888888888888889
# Lift: 3.304419661296985
# =====================================
# Rule: yogurt -> bottled water
# Support: 0.01
# Confidence: 0.5555555555555556
# Lift: 4.374453193350831
# =====================================
# Rule: root vegetables -> butter
# Support: 0.017
# Confidence: 0.3695652173913044
# Lift: 3.3596837944664033
# =====================================
# Rule: root vegetables -> butter
# Support: 0.012
# Confidence: 0.46153846153846156
# Lift: 4.195804195804196
# =====================================
# Rule: butter -> whole milk
# Support: 0.008
# Confidence: 0.3076923076923077
# Lift: 3.1720856463124507
# =====================================
# Rule: whipped/sour cream -> butter
# Support: 0.008
# Confidence: 0.3076923076923077
# Lift: 4.158004158004158
# =====================================
# Rule: yogurt -> butter
# Support: 0.008
# Confidence: 0.888888888888889
# Lift: 3.304419661296985
# =====================================
# Rule: candy -> nan
# Support: 0.009
# Confidence: 0.35999999999999993
# Lift: 3.7113402061855663
# =====================================
# Rule: long life bakery product -> nan
# Support: 0.008
# Confidence: 0.3076923076923077
# Lift: 4.048582995951417
# =====================================
# Rule: nan -> curd
# Support: 0.009
# Confidence: 0.3214285714285714
# Lift: 4.285714285714286
# =====================================
# Rule: yogurt -> rolls/buns
# Support: 0.009
# Confidence: 0.4285714285714285
# Lift: 3.3745781777277832
# =====================================
# Rule: yogurt -> whipped/sour cream
# Support: 0.008
# Confidence: 0.6153846153846154
# Lift: 4.845548152634767
# =====================================
# Rule: yogurt -> curd
# Support: 0.016
# Confidence: 0.48484848484848486
# Lift: 3.81770460510618
# =====================================
# Rule: other vegetables -> fruit/vegetable juice
# Support: 0.01
# Confidence: 0.47619047619047616
# Lift: 4.909180166912125
# =====================================
# Rule: yogurt -> other vegetables
# Support: 0.01
# Confidence: 0.47619047619047616
# Lift: 3.7495313085864264
# =====================================
# Rule: yogurt -> fruit/vegetable juice
# Support: 0.015
# Confidence: 0.5172413793103448
# Lift: 4.072766766223187
# =====================================
# Rule: whipped/sour cream -> nan
# Support: 0.008
# Confidence: 0.38095238095238093
# Lift: 5.148005148005148
# =====================================
# Rule: nan -> hard cheese
# Support: 0.009
# Confidence: 0.37499999999999994
# Lift: 3.865979381443298
# =====================================
# Rule: oil -> nan
# Support: 0.01
# Confidence: 0.33333333333333337
# Lift: 3.745318352059926
# =====================================
# Rule: root vegetables -> packaged fruit/vegetables
# Support: 0.011
# Confidence: 0.3333333333333333
# Lift: 3.0303030303030303
# =====================================
# Rule: pip fruit -> nan
# Support: 0.013
# Confidence: 0.31707317073170727
# Lift: 3.268795574553683
# =====================================
# Rule: yogurt -> nan
# Support: 0.011
# Confidence: 0.39285714285714285
# Lift: 3.093363329583802
# =====================================
# Rule: yogurt -> napkins
# Support: 0.011
# Confidence: 0.5499999999999999
# Lift: 4.330708661417322
# =====================================
# Rule: root vegetables -> other vegetables
# Support: 0.013
# Confidence: 0.3023255813953489
# Lift: 3.116758571086071
# =====================================
# Rule: whipped/sour cream -> other vegetables
# Support: 0.009
# Confidence: 0.7499999999999999
# Lift: 4.032258064516128
# =====================================
# Rule: sausage -> rolls/buns
# Support: 0.009
# Confidence: 0.3214285714285714
# Lift: 4.1208791208791204
# =====================================
# Rule: root vegetables -> whole milk
# Support: 0.013
# Confidence: 0.35135135135135137
# Lift: 3.194103194103194
# =====================================
# Rule: yogurt -> root vegetables
# Support: 0.01
# Confidence: 0.38461538461538464
# Lift: 3.0284675953967293
# =====================================
# Rule: sausage -> yogurt
# Support: 0.008
# Confidence: 0.4
# Lift: 3.1496062992125986
# =====================================
# Rule: sausage -> yogurt
# Support: 0.011
# Confidence: 0.4230769230769231
# Lift: 3.331314354936402
# =====================================
# Rule: whipped/sour cream -> whole milk
# Support: 0.01
# Confidence: 0.8333333333333334
# Lift: 3.097893432465923
# =====================================
# Rule: yogurt -> whole milk
# Support: 0.015
# Confidence: 0.40540540540540543
# Lift: 3.1921685464992553
# =====================================
# Rule: yogurt -> whipped/sour cream
# Support: 0.013
# Confidence: 0.8125
# Lift: 3.020446096654275
# =====================================
# Rule: beef -> nan
# Support: 0.01
# Confidence: 0.3703703703703704
# Lift: 3.367003367003367
# =====================================
# Rule: root vegetables -> nan
# Support: 0.008
# Confidence: 0.36363636363636365
# Lift: 3.3057851239669422
# =====================================
# Rule: whipped/sour cream -> nan
# Support: 0.01
# Confidence: 0.4545454545454546
# Lift: 6.142506142506144
# =====================================
# Rule: yogurt -> citrus fruit
# Support: 0.008
# Confidence: 0.47058823529411764
# Lift: 3.7054191755442334
# =====================================
# Rule: domestic eggs -> nan
# Support: 0.008
# Confidence: 0.888888888888889
# Lift: 3.304419661296985
# =====================================
# Rule: yogurt -> nan
# Support: 0.01
# Confidence: 0.5555555555555556
# Lift: 4.374453193350831
# =====================================
# Rule: root vegetables -> butter
# Support: 0.012
# Confidence: 0.46153846153846156
# Lift: 4.195804195804196
# =====================================
# Rule: tropical fruit -> butter
# Support: 0.008
# Confidence: 0.3076923076923077
# Lift: 3.1720856463124507
# =====================================
# Rule: whipped/sour cream -> butter
# Support: 0.008
# Confidence: 0.3076923076923077
# Lift: 4.158004158004158
# =====================================
# Rule: yogurt -> butter
# Support: 0.008
# Confidence: 0.888888888888889
# Lift: 3.304419661296985
# =====================================
# Rule: yogurt -> rolls/buns
# Support: 0.009
# Confidence: 0.4285714285714285
# Lift: 3.3745781777277832
# =====================================
# Rule: yogurt -> whipped/sour cream
# Support: 0.008
# Confidence: 0.6153846153846154
# Lift: 4.845548152634767
# =====================================
# Rule: yogurt -> nan
# Support: 0.016
# Confidence: 0.48484848484848486
# Lift: 3.81770460510618
# =====================================
# Rule: other vegetables -> nan
# Support: 0.01
# Confidence: 0.47619047619047616
# Lift: 4.909180166912125
# =====================================
# Rule: yogurt -> other vegetables
# Support: 0.01
# Confidence: 0.47619047619047616
# Lift: 3.7495313085864264
# =====================================
# Rule: yogurt -> nan
# Support: 0.015
# Confidence: 0.5172413793103448
# Lift: 4.072766766223187
# =====================================
# Rule: yogurt -> other vegetables
# Support: 0.009
# Confidence: 0.4285714285714285
# Lift: 7.653061224489794
# =====================================
# Rule: yogurt -> nan
# Support: 0.011
# Confidence: 0.5499999999999999
# Lift: 4.330708661417322
# =====================================
# Rule: root vegetables -> other vegetables
# Support: 0.013
# Confidence: 0.3023255813953489
# Lift: 3.116758571086071
# =====================================
# Rule: whipped/sour cream -> other vegetables
# Support: 0.009
# Confidence: 0.7499999999999999
# Lift: 4.032258064516128
# =====================================
# Rule: sausage -> rolls/buns
# Support: 0.009
# Confidence: 0.3214285714285714
# Lift: 4.1208791208791204
# =====================================
# Rule: root vegetables -> nan
# Support: 0.013
# Confidence: 0.35135135135135137
# Lift: 3.194103194103194
# =====================================
# Rule: yogurt -> root vegetables
# Support: 0.01
# Confidence: 0.38461538461538464
# Lift: 3.0284675953967293
# =====================================
# Rule: sausage -> yogurt
# Support: 0.008
# Confidence: 0.4
# Lift: 3.1496062992125986
# =====================================
# Rule: sausage -> yogurt
# Support: 0.011
# Confidence: 0.4230769230769231
# Lift: 3.331314354936402
# =====================================
# Rule: whipped/sour cream -> nan
# Support: 0.01
# Confidence: 0.8333333333333334
# Lift: 3.097893432465923
# =====================================
# Rule: yogurt -> nan
# Support: 0.015
# Confidence: 0.40540540540540543
# Lift: 3.1921685464992553
# =====================================
# Rule: yogurt -> whipped/sour cream
# Support: 0.013
# Confidence: 0.8125
# Lift: 3.020446096654275
# =====================================
# Rule: yogurt -> whole milk
# Support: 0.009
# Confidence: 0.4285714285714285
# Lift: 7.653061224489794
# =====================================
